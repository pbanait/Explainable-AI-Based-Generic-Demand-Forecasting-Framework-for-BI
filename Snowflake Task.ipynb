# %%
# %pip install snowflake-connector-python

# %%
# %run ./connection

# %%
import snowflake.connector

conn = snowflake.connector.connect(**python_connector_params)
cursor = conn.cursor()
cursor.execute("EXECUTE TASK LOAD_SALES_ORDER_TASK")
cursor.close()
conn.close()
